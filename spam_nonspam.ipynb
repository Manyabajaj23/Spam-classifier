# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("spam.csv",encoding="ISO-8859-1")

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 4066  spam  You are being contacted by our Dating Service ...        NaN
# 2859   ham  I want to be there so i can kiss you and feel ...        NaN
# 1848   ham  I dont want to hear philosophy. Just say what ...        NaN
# 5534   ham                       Ok which your another number        NaN
# 2050   ham              Hi where you. You in home or calicut?        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4066        NaN        NaN
# 2859        NaN        NaN
# 1848        NaN        NaN
# 5534        NaN        NaN
# 2050        NaN        NaN

# %%
df.head(5)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.tail(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.rename(columns={"v1": "target","v2":"text"},inplace=True)

# %%
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df["target"]=encoder.fit_transform(df["target"])

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df=df.drop_duplicates(keep="first")

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df["target"].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df["target"].value_counts(),labels=["ham","spam"],autopct="%0.3f")
# Out:
# ([<matplotlib.patches.Wedge at 0x1bae0374cb0>,
# ...
#  [Text(-1.014499732282844, 0.4251944181172162, 'ham'),
#   Text(1.0144998708287172, -0.42519408755122207, 'spam')],
#  [Text(-0.5533634903360967, 0.2319242280639361, '87.367'),
#   Text(0.553363565906573, -0.231924047755212, '12.633')])

# %%
# pip install nltk

# %%
import nltk

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\JAYA
# [nltk_data]     BAJAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
tokenized_word=[]

# %%
for x in df["text"]:
    a=word_tokenize(x)
    tokenized_word.append(len(a))
tokenized_word
# Out:
# [24,
#  8,
#  37,
#  13,
#  15,
#  39,
#  18,
#  31,
#  32,
#  31,
#  28,
#  31,
#  32,
#  41,
#  10,
#  28,
#  9,
#  22,
#  14,
#  28,
#  9,
#  11,
#  13,
#  23,
#  13,
#  35,
#  6,
#  34,
#  22,
#  16,
#  30,
#  48,
#  7,
#  18,
#  30,
#  30,
#  12,
#  8,
#  6,
#  37,
#  20,
#  35,
#  34,
#  5,
#  22,
#  7,
#  10,
#  7,
#  16,
#  37,
#  14,
#  35,
#  17,
#  69,
#  27,
#  20,
#  37,
#  9,
#  4,
#  10,
#  29,
#  11,
#  6,
#  14,
#  26,
#  31,
#  29,
#  34,
#  20,
#  9,
#  11,
#  6,
#  12,
#  14,
#  6,
#  11,
#  16,
#  14,
#  13,
#  20,
#  6,
#  9,
#  10,
#  9,
#  4,
#  16,
#  30,
#  36,
#  10,
#  11,
#  12,
#  44,
#  28,
#  24,
#  23,
#  26,
#  8,
#  13,
#  47,
#  14,
#  23,
#  19,
#  44,
#  10,
#  19,
#  12,
#  15,
#  28,
#  9,
#  9,
#  6,
#  28,
#  33,
#  34,
#  40,
#  32,
#  14,
#  20,
#  23,
#  30,
#  12,
#  29,
#  14,
#  9,
#  6,
#  56,
#  6,
#  31,
#  11,
#  4,
#  7,
#  5,
#  29,
#  36,
#  10,
#  9,
#  10,
#  35,
#  24,
#  10,
#  7,
#  34,
#  12,
#  7,
#  11,
#  35,
#  16,
# ...

# %%
df["num_words"]=tokenized_word
# Out:
# C:\Users\JAYA BAJAJ\AppData\Local\Temp\ipykernel_16092\1460562130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_words"]=tokenized_word

# %%
df
# Out:
#       target                                               text  num_words
# 0          0  Go until jurong point, crazy.. Available only ...         24
# 1          0                      Ok lar... Joking wif u oni...          8
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...         37
# 3          0  U dun say so early hor... U c already then say...         13
# 4          0  Nah I don't think he goes to usf, he lives aro...         15
# ...      ...                                                ...        ...
# 5567       1  This is the 2nd time we have tried 2 contact u...         35
# 5568       0              Will Ì_ b going to esplanade fr home?          9
# 5569       0  Pity, * was in mood for that. So...any other s...         15
# 5570       0  The guy did some bitching but I acted like i'd...         27
# 5571       0                         Rofl. Its true to its name          7
#
# [5169 rows x 3 columns]

# %%
num_characters=[]
for x in df["text"]:
   num_characters.append(len(x))
num_characters
# Out:
# [111,
#  29,
#  155,
#  49,
#  61,
#  148,
#  77,
#  160,
#  158,
#  154,
#  109,
#  136,
#  156,
#  196,
#  35,
#  149,
#  26,
#  81,
#  58,
#  156,
#  41,
#  49,
#  53,
#  88,
#  57,
#  144,
#  30,
#  134,
#  75,
#  64,
#  130,
#  189,
#  29,
#  84,
#  159,
#  123,
#  47,
#  28,
#  27,
#  155,
#  82,
#  142,
#  172,
#  19,
#  72,
#  32,
#  45,
#  31,
#  67,
#  148,
#  58,
#  124,
#  80,
#  291,
#  120,
#  76,
#  161,
#  34,
#  22,
#  40,
#  108,
#  48,
#  25,
#  56,
#  110,
#  153,
#  124,
#  161,
#  80,
#  34,
#  46,
#  29,
#  45,
#  42,
#  20,
#  43,
#  73,
#  50,
#  42,
#  76,
#  22,
#  32,
#  32,
#  36,
#  14,
#  55,
#  121,
#  144,
#  42,
#  41,
#  62,
#  195,
#  141,
#  139,
#  107,
#  125,
#  33,
#  51,
#  184,
#  57,
#  81,
#  76,
#  183,
#  44,
#  95,
#  43,
#  82,
#  115,
#  30,
#  40,
#  31,
#  96,
#  159,
#  143,
#  156,
#  153,
#  72,
#  86,
#  144,
#  157,
#  53,
#  156,
#  52,
#  40,
#  20,
#  244,
#  22,
#  107,
#  28,
#  9,
#  39,
#  25,
#  126,
#  162,
#  38,
# ...

# %%
df["num_characters"]=num_characters
# Out:
# C:\Users\JAYA BAJAJ\AppData\Local\Temp\ipykernel_16092\3628003891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_characters"]=num_characters

# %%
df
# Out:
#       target                                               text  num_words  \
# 0          0  Go until jurong point, crazy.. Available only ...         24
# 1          0                      Ok lar... Joking wif u oni...          8
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...         37
# 3          0  U dun say so early hor... U c already then say...         13
# 4          0  Nah I don't think he goes to usf, he lives aro...         15
# ...      ...                                                ...        ...
# 5567       1  This is the 2nd time we have tried 2 contact u...         35
# 5568       0              Will Ì_ b going to esplanade fr home?          9
# 5569       0  Pity, * was in mood for that. So...any other s...         15
# 5570       0  The guy did some bitching but I acted like i'd...         27
# 5571       0                         Rofl. Its true to its name          7
#
#       num_characters
# 0                111
# 1                 29
# ...

# %%
from nltk.tokenize import sent_tokenize

# %%
tokenized_sent=[]

# %%
for y in df["text"]:
    b=sent_tokenize(y)
    tokenized_sent.append(len(b))
tokenized_sent
# Out:
# [2,
#  2,
#  2,
#  1,
#  1,
#  4,
#  2,
#  2,
#  5,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  1,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  3,
#  2,
#  6,
#  1,
#  5,
#  1,
#  5,
#  1,
#  6,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  4,
#  4,
#  4,
#  2,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  4,
#  2,
#  1,
#  1,
#  6,
#  5,
#  2,
#  7,
#  1,
#  1,
#  1,
#  3,
#  2,
#  1,
#  1,
#  2,
#  2,
#  2,
#  3,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  3,
#  3,
#  1,
#  1,
#  2,
#  4,
#  2,
#  1,
#  3,
#  4,
#  1,
#  2,
#  5,
#  2,
#  3,
#  2,
#  5,
#  1,
#  2,
#  1,
#  1,
#  4,
#  2,
#  1,
#  1,
#  3,
#  7,
#  3,
#  6,
#  1,
#  2,
#  2,
#  3,
#  4,
#  1,
#  2,
#  2,
#  1,
#  1,
#  4,
#  1,
#  5,
#  1,
#  1,
#  1,
#  1,
#  3,
#  6,
#  2,
#  2,
#  2,
#  2,
#  4,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  5,
#  1,
#  1,
#  6,
#  3,
#  1,
#  1,
#  2,
#  3,
#  3,
#  5,
#  1,
#  6,
#  1,
# ...

# %%
df["num_sentences"]=tokenized_sent
df
# Out:
# C:\Users\JAYA BAJAJ\AppData\Local\Temp\ipykernel_16092\674651369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_sentences"]=tokenized_sent
#       target                                               text  num_words  \
# 0          0  Go until jurong point, crazy.. Available only ...         24
# 1          0                      Ok lar... Joking wif u oni...          8
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...         37
# 3          0  U dun say so early hor... U c already then say...         13
# 4          0  Nah I don't think he goes to usf, he lives aro...         15
# ...      ...                                                ...        ...
# ...

# %%
num_characters=[]
for y in df["text"]:
    num_characters.append(len(y))
num_characters
# Out:
# [111,
#  29,
#  155,
#  49,
#  61,
#  148,
#  77,
#  160,
#  158,
#  154,
#  109,
#  136,
#  156,
#  196,
#  35,
#  149,
#  26,
#  81,
#  58,
#  156,
#  41,
#  49,
#  53,
#  88,
#  57,
#  144,
#  30,
#  134,
#  75,
#  64,
#  130,
#  189,
#  29,
#  84,
#  159,
#  123,
#  47,
#  28,
#  27,
#  155,
#  82,
#  142,
#  172,
#  19,
#  72,
#  32,
#  45,
#  31,
#  67,
#  148,
#  58,
#  124,
#  80,
#  291,
#  120,
#  76,
#  161,
#  34,
#  22,
#  40,
#  108,
#  48,
#  25,
#  56,
#  110,
#  153,
#  124,
#  161,
#  80,
#  34,
#  46,
#  29,
#  45,
#  42,
#  20,
#  43,
#  73,
#  50,
#  42,
#  76,
#  22,
#  32,
#  32,
#  36,
#  14,
#  55,
#  121,
#  144,
#  42,
#  41,
#  62,
#  195,
#  141,
#  139,
#  107,
#  125,
#  33,
#  51,
#  184,
#  57,
#  81,
#  76,
#  183,
#  44,
#  95,
#  43,
#  82,
#  115,
#  30,
#  40,
#  31,
#  96,
#  159,
#  143,
#  156,
#  153,
#  72,
#  86,
#  144,
#  157,
#  53,
#  156,
#  52,
#  40,
#  20,
#  244,
#  22,
#  107,
#  28,
#  9,
#  39,
#  25,
#  126,
#  162,
#  38,
# ...

# %%
df.columns
# Out:
# Index(['target', 'text', 'num_words', 'num_characters', 'num_sentences'], dtype='object')

# %%
df[['num_words', 'num_characters',
       'num_sentences']].describe()
# Out:
#          num_words  num_characters  num_sentences
# count  5169.000000     5169.000000    5169.000000
# mean     18.455794       78.977945       1.965564
# std      13.324758       58.236293       1.448541
# min       1.000000        2.000000       1.000000
# 25%       9.000000       36.000000       1.000000
# 50%      15.000000       60.000000       1.000000
# 75%      26.000000      117.000000       2.000000
# max     220.000000      910.000000      38.000000

# %%
df[df["target"]==0][['num_words', 'num_characters','num_sentences']].describe()  #ham messages
# Out:
#          num_words  num_characters  num_sentences
# count  4516.000000     4516.000000    4516.000000
# mean     17.123782       70.459256       1.820195
# std      13.493970       56.358207       1.383657
# min       1.000000        2.000000       1.000000
# 25%       8.000000       34.000000       1.000000
# 50%      13.000000       52.000000       1.000000
# 75%      22.000000       90.000000       2.000000
# max     220.000000      910.000000      38.000000

# %%
df[df["target"]==1][['num_words', 'num_characters','num_sentences']].describe()  #spam messages
# Out:
#         num_words  num_characters  num_sentences
# count  653.000000      653.000000     653.000000
# mean    27.667688      137.891271       2.970904
# std      7.008418       30.137753       1.488425
# min      2.000000       13.000000       1.000000
# 25%     25.000000      132.000000       2.000000
# 50%     29.000000      149.000000       3.000000
# 75%     32.000000      157.000000       4.000000
# max     46.000000      224.000000       9.000000

# %% [markdown]
# spam messages avg is larger than ham message avg

# %%
import seaborn as sns

# %%
sns.histplot(df[df["target"]==0]["num_characters"])
sns.histplot(df[df["target"]==1]["num_characters"],color="red")
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.pairplot(df,hue="target")

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
from nltk.stem.porter import PorterStemmer 
ps=PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\JAYA
# [nltk_data]     BAJAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
ps.stem("runs")
# Out:
# 'run'

# %%
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words("english") and i not in string.punctuation:
            y.append(i)
    text=y[:]
    y.clear()  
    for i in text:
        y.append(ps.stem(i))  
    return " ".join(y)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df["transformed_text"]=df["text"].apply(transform_text)
# Out:
# C:\Users\JAYA BAJAJ\AppData\Local\Temp\ipykernel_16092\958737439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["transformed_text"]=df["text"].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_words  \
# 0       0  Go until jurong point, crazy.. Available only ...         24
# 1       0                      Ok lar... Joking wif u oni...          8
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...         37
# 3       0  U dun say so early hor... U c already then say...         13
# 4       0  Nah I don't think he goes to usf, he lives aro...         15
#
#    num_characters  num_sentences  \
# 0             111              2
# 1              29              2
# 2             155              2
# 3              49              1
# 4              61              1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
pip install WordCloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(width=800, height=400, min_font_size=10,background_color='white')
spam_wc=wordcloud.generate(df[df["target"]==1]["transformed_text"].str.cat(sep=" "))
plt.figure(figsize=(10, 5))
plt.imshow(spam_wc)

# %%
wordcloud = WordCloud(width=800, height=400, min_font_size=10,background_color='white')
ham_wc=wordcloud.generate(df[df["target"]==0]["transformed_text"].str.cat(sep=" "))
plt.figure(figsize=(10, 5))
plt.imshow(ham_wc)

# %%
df[df["target"]==1]
# Out:
#       target                                               text  num_words  \
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...         37
# 5          1  FreeMsg Hey there darling it's been 3 week's n...         39
# 8          1  WINNER!! As a valued network customer you have...         32
# 9          1  Had your mobile 11 months or more? U R entitle...         31
# 11         1  SIX chances to win CASH! From 100 to 20,000 po...         31
# ...      ...                                                ...        ...
# 5537       1  Want explicit SEX in 30 secs? Ring 02073162414...         18
# 5540       1  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...         38
# 5547       1  Had your contract mobile 11 Mnths? Latest Moto...         35
# 5566       1  REMINDER FROM O2: To get 2.50 pounds free call...         30
# 5567       1  This is the 2nd time we have tried 2 contact u...         35
#
#       num_characters  num_sentences  \
# ...

# %%
spam_corpus=[]
for msg in df[df["target"]==1]["transformed_text"].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
ham_corpus=[]
for msg in df[df["target"]==0]["transformed_text"].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
df.head()
# Out:
#    target                                               text  num_words  \
# 0       0  Go until jurong point, crazy.. Available only ...         24
# 1       0                      Ok lar... Joking wif u oni...          8
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...         37
# 3       0  U dun say so early hor... U c already then say...         13
# 4       0  Nah I don't think he goes to usf, he lives aro...         15
#
#    num_characters  num_sentences  \
# 0             111              2
# 1              29              2
# 2             155              2
# 3              49              1
# 4              61              1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import CountVectorizer , TfidfVectorizer

# %%
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
# docs = [
#     "I love apples",
#     "I love bananas",
#     "Apples and bananas are good"
# ]
# X = tfidf.fit_transform(docs)

# %%
# tfidf.get_feature_names_out()

# %%
x=tfidf.fit_transform(df["transformed_text"]).toarray()

# %%
x.shape
# Out:
# (5169, 3000)

# %%
y=df["target"].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred1=gnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8626692456479691
# [[771 118]
#  [ 24 121]]
# 0.5062761506276151

# %%
mnb.fit(x_train,y_train)
y_pred1=mnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9729206963249516
# [[888   1]
#  [ 27 118]]
# 0.9915966386554622

# %%
bnb.fit(x_train,y_train)
y_pred1=bnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9729206963249516
# [[884   5]
#  [ 23 122]]
# 0.9606299212598425

# %%
import pickle
pickle.dump(tfidf,open("vectorizer.pkl","wb"))
pickle.dump(mnb,open("model.pkl","wb"))
